# %% [markdown]
# # **What kind of data does pandas handle?**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np



pop_data=pd.read_csv('/content/drive/MyDrive/pak_population.csv')
pop_data1=pd.read_csv('/content/drive/MyDrive/pakistan_population.csv')

pop_data1.head()

# pop_data.describe()
# pop_data.head()
# pop_data.dtypes
# pop_data.info()
# Out:
#    Year  Population  Yearly % Change  Yearly Change  Migrants (net)  \
# 0  2020   220892340             2.00        4327022         -233379
# 1  2019   216565318             2.04        4337032         -233379
# 2  2018   212228286             2.08        4322077         -233379
# 3  2017   207906209             2.10        4274856         -233379
# 4  2016   203631353             2.11        4204389         -233379
#
#    Median Age  Fertility Rate  Density (P/Km²)  Urban Pop %  Urban Population  \
# 0        22.8            3.55              287         35.1          77437729
# 1        22.0            3.73              281         34.9          75510639
# 2        22.0            3.73              275         34.7          73630430
# 3        22.0            3.73              270         34.5          71795700
# 4        22.0            3.73              264         34.4          70005271
#
#    Country's Share of World Pop  World Population  Pakistan Global Rank
# ...

# %% [markdown]
# # **How do I read and write tabular data?**

# %%
pop_data.head(8)
# pop_data
# Out:
#   PROVINCE             DIVISION               DISTRICT  \
# 0   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 1   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 2   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 3   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 4   PUNJAB  BAHAWALPUR DIVISION  BAHAWALNAGAR DISTRICT
# 5   PUNJAB  BAHAWALPUR DIVISION    BAHAWALPUR DISTRICT
# 6   PUNJAB  BAHAWALPUR DIVISION    BAHAWALPUR DISTRICT
# 7   PUNJAB  BAHAWALPUR DIVISION    BAHAWALPUR DISTRICT
#
#                SUB DIVISION  AREA (sq.km)  ALL SEXES (RURAL)  MALE (RURAL)  \
# 0       BAHAWALNAGAR TEHSIL        1729.0             619550        316864
# 1          CHISHTIAN TEHSIL        1500.0             540342        273788
# 2         FORT ABBAS TEHSIL        2536.0             361240        182655
# 3         HAROONABAD TEHSIL        1295.0             382115        192278
# 4        MINCHINABAD TEHSIL        1818.0             452723        231506
# ...

# %% [markdown]
# # **How do I select a subset of a DataFrame?**

# %%
pop_data[['PROVINCE','ALL SEXES (RURAL)']]
type(pop_data[['PROVINCE','ALL SEXES (RURAL)']])
pop_data[['PROVINCE','ALL SEXES (RURAL)']].shape




# pop_data[['ALL SEXES (RURAL)','MALE (RURAL)','FEMALE (RURAL)','ALL SEXES (URBAN)','MALE (URBAN)','FEMALE (URBAN)']]
# pop_data[['ALL SEXES (RURAL)','MALE (RURAL)','FEMALE (RURAL)','ALL SEXES (URBAN)','MALE (URBAN)','FEMALE (URBAN)']]

# %% [markdown]
# # **How do I filter specific rows from a DataFrame?**

# %%
# pop_data.head()
# pop_data[pop_data['AREA (sq.km)']>10000]
punjab=pop_data[pop_data['PROVINCE'] == 'PUNJAB']
punjab
punjab.shape
# Out:
# (143, 49)

# %% [markdown]
# # **How do I select specific rows and columns from a DataFrame?**

# %%
sex=pop_data.loc[pop_data['PROVINCE'] == 'PUNJAB',"ALL SEXES (RURAL)"]
sex

# %% [markdown]
# # **How do I create plots in pandas?**

# %%
# pop_data[['PROVINCE','DISTRICT', 'SEX RATIO (RURAL)']].plot()
pop_data["SEX RATIO (URBAN)"].plot()


plt.show()

# %% [markdown]
# # **How to calculate summary statistics**

# %%
pop_data[['ALL SEXES (RURAL)','MALE (RURAL)','FEMALE (RURAL)','ALL SEXES (URBAN)','MALE (URBAN)','FEMALE (URBAN)']].mean()
pop_data[['ALL SEXES (RURAL)','MALE (RURAL)','FEMALE (RURAL)','ALL SEXES (URBAN)','MALE (URBAN)','FEMALE (URBAN)']].max()

pop_data[['ALL SEXES (RURAL)','MALE (RURAL)','FEMALE (RURAL)','ALL SEXES (URBAN)','MALE (URBAN)','FEMALE (URBAN)']].median()

# %% [markdown]
# # **How to reshape the layout of tables**
# **Sort table rows**

# %%
 pop_data.sort_values(by=['PROVINCE', 'ALL SEXES (RURAL)'], ascending=False).head()

# %%
from google.colab import drive
drive.mount('/content/drive')
